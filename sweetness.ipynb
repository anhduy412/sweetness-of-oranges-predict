# %% [markdown]
# 1. Load the image
# 2. Preprocess the image
# 3. Extract the feature
# 4. Select the feature
# 5. Encode the feature
# 6. Train or test the model
# 7. Estimate

# %%
# 1. Load the image
from PIL import Image
import numpy as np

def load_image( infilename ) :
    img = Image.open( infilename )
    img.load()
    data = np.asarray(img, dtype="int32" )
    return data

# def save_image( npdata, outfilename ) :
#     img = Image.fromarray( np.asarray( np.clip(npdata,0,255), dtype="uint8"), "L" )
#     img.save( outfilename )

# %%
import glob
from scipy import ndimage
import pandas as pd
path = 'C:/Users/nguye/Downloads/Dulieu/*.jpeg'
# path ='Dulieu/*.jpeg' # Chỗ này mn tự thay path trong laptop mn ạ
img_name = glob.glob(path)
rgb_list = []
label_feature_list = []
for img in img_name:
    img = Image.open(img)
    reduced = img.convert("P", palette=Image.Palette.WEB) # convert to web palette (216 colors)
    palette = reduced.getpalette() # get palette as [r,g,b,r,g,b,...]
    palette = [palette[3*n:3*n+3] for n in range(256)] # group 3 by 3 = [[r,g,b],[r,g,b],...]
    color_count = [(n, palette[m]) for n,m in reduced.getcolors()]
    RGB_df = pd.DataFrame(color_count, columns = ['cnt', 'RGB']).sort_values(by = 'cnt', ascending = False).iloc[1:6]
    RGB = pd.DataFrame(RGB_df['RGB'].to_list(), columns = ['r', 'g', 'b'])
    color = RGB.mean()
    rgb_list.append(color)
    img_arr = np.asarray( img, dtype="int32" )
    labeled_image, num_features = ndimage.label(img_arr)
    label_feature_list.append(num_features)

# %%
color_frame = pd.DataFrame(rgb_list, columns = ['r' ,'g','b'])
color_frame = color_frame.astype(float)

# %%
color_frame['img'] = img_name
color_frame['img_name'] = color_frame['img'].str.extract(r"\\(.*?)_")
color_frame.drop(columns = ['img'], inplace = True)
color_frame
# Out:
#           r      g     b img_name
# 0     122.4  122.4  40.8      A10
# 1     122.4  122.4  40.8      A10
# 2     122.4  102.0  40.8      A10
# 3     132.6  112.2  30.6      A10
# 4     132.6  112.2  30.6      A10
# ...     ...    ...   ...      ...
# 8984  132.6  112.2  30.6       C9
# 8985  132.6  112.2  30.6       C9
# 8986  132.6  112.2  30.6       C9
# 8987  132.6  112.2  30.6       C9
# 8988  132.6  112.2  30.6       C9
#
# [8989 rows x 4 columns]

# %%
color_frame = color_frame.groupby(by=["img_name"]).mean().reset_index()
color_frame
# Out:
#    img_name        r        g       b
# 0        A1  139.332  115.872  28.152
# 1       A10  129.540  114.852  33.660
# 2       A11  148.716  124.338  30.396
# 3       A12  146.166  122.502  31.110
# 4       A13  166.974  131.478  31.722
# ..      ...      ...      ...     ...
# 85       C5  162.996  117.504  27.234
# 86       C6  153.102  120.564  35.802
# 87       C7  145.248  118.320  37.026
# 88       C8  129.132  108.834  41.310
# 89       C9  135.864  113.832  32.232
#
# [90 rows x 4 columns]

# %%
label = pd.DataFrame(label_feature_list, columns = ['label_feature']) 
label['img'] = img_name
label['img_name'] = label['img'].str.extract(r"\\(.*?)_")
label.drop(columns = ['img'], inplace = True)
label
# Out:
#       label_feature img_name
# 0                90      A10
# 1               110      A10
# 2               115      A10
# 3               110      A10
# 4                89      A10
# ...             ...      ...
# 8984             69       C9
# 8985             68       C9
# 8986             64       C9
# 8987             80       C9
# 8988             62       C9
#
# [8989 rows x 2 columns]

# %%
label = label.groupby(by=["img_name"]).mean().reset_index()
label
# Out:
#    img_name  label_feature
# 0        A1          98.74
# 1       A10          94.41
# 2       A11          93.47
# 3       A12          90.28
# 4       A13          94.77
# ..      ...            ...
# 85       C5          71.06
# 86       C6          75.05
# 87       C7          77.35
# 88       C8          74.59
# 89       C9          73.42
#
# [90 rows x 2 columns]

# %%
data = pd.read_excel('C:/Users/nguye/Downloads/Dulieu/Độ_acid_cam.xlsx')
data.head()
# Out:
#   Name    p  C NaOH  Khối lượng(g)  Đường kính ngang(mm)  Đường kính dọc(mm)  \
# 0   A1  1.9  0.4000            255                   257                 262
# 1   A2  1.2  0.4000            325                   288                 278
# 2   A3  2.3  0.4000            185                   235                 237
# 3   A4  1.4  0.4128            203                   245                 245
# 4   A5  1.2  0.4000            229                   253                 249
#
#    Độ đường (Brix %)    TA (%)   Brix:TA     BrmTA
# 0               10.9  4.867141  2.239508  6.032859
# 1                9.8  3.073984  3.188045  6.726016
# 2               11.0  5.891803  1.867001  5.108197
# 3                9.0  3.701077  2.431725  5.298923
# 4               10.9  3.073984  3.545887  7.826016

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  81 non-null     object
#  1   p                     81 non-null     float64
#  2   C NaOH                81 non-null     float64
#  3   Khối lượng(g)         81 non-null     int64
#  4   Đường kính ngang(mm)  81 non-null     int64
#  5   Đường kính dọc(mm)    81 non-null     int64
#  6   Độ đường (Brix %)     81 non-null     float64
#  7   TA (%)                81 non-null     float64
#  8   Brix:TA               81 non-null     float64
#  9   BrmTA                 81 non-null     float64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 6.5+ KB

# %%
data = data.merge(color_frame, how = 'left', left_on = 'Name', right_on = 'img_name')

# %%
data = data.merge( label, how = 'left', left_on = 'Name', right_on = 'img_name')

# %%
data
# Out:
#    Name     p  C NaOH  Khối lượng(g)  Đường kính ngang(mm)  \
# 0    A1  1.90  0.4000            255                   257
# 1    A2  1.20  0.4000            325                   288
# 2    A3  2.30  0.4000            185                   235
# 3    A4  1.40  0.4128            203                   245
# 4    A5  1.20  0.4000            229                   253
# ..  ...   ...     ...            ...                   ...
# 76  C24  1.60  0.4016            177                   225
# 77  C25  1.60  0.4016            173                   216
# 78  C26  0.95  0.4016            126                   195
# 79  C28  1.70  0.4016            181                   216
# 80  C29  1.35  0.4230            166                   214
#
#     Đường kính dọc(mm)  Độ đường (Brix %)    TA (%)   Brix:TA      BrmTA  \
# 0                  262               10.9  4.867141  2.239508   6.032859
# 1                  278                9.8  3.073984  3.188045   6.726016
# 2                  237               11.0  5.891803  1.867001   5.108197
# 3                  245                9.0  3.701077  2.431725   5.298923
# 4                  249               10.9  3.073984  3.545887   7.826016
# ..                 ...                ...       ...       ...        ...
# 76                 216               12.5  4.115040  3.037638   8.384960
# 77                 220               11.1  4.115040  2.697422   6.984960
# 78                 197               12.8  2.443305  5.238806  10.356695
# 79                 232               11.8  4.372230  2.698852   7.427770
# 80                 214               12.3  3.657080  3.363339   8.642920
#
#    img_name_x           r           g          b img_name_y  label_feature
# 0          A1  139.332000  115.872000  28.152000         A1      98.740000
# 1          A2  147.213462  120.732692  33.934615         A2      94.298077
# 2          A3  160.854000  129.030000  33.966000         A3      69.520000
# 3          A4  158.814000  130.866000  30.906000         A4      82.210000
# 4          A5  144.636000  118.422000  36.414000         A5      93.710000
# ..        ...         ...         ...        ...        ...            ...
# 76        C24  140.352000  115.974000  34.068000        C24      76.920000
# 77        C25  149.226000  119.544000  35.802000        C25      74.790000
# 78        C26  131.682000  110.058000  31.620000        C26      72.620000
# 79        C28  143.106000  117.300000  35.496000        C28      77.030000
# 80        C29  138.108000  113.424000  31.926000        C29      70.760000
#
# [81 rows x 16 columns]

# %%
data.drop(columns = ['img_name_x','img_name_y'], inplace = True)

# %%
data
# Out:
#    Name     p  C NaOH  Khối lượng(g)  Đường kính ngang(mm)  \
# 0    A1  1.90  0.4000            255                   257
# 1    A2  1.20  0.4000            325                   288
# 2    A3  2.30  0.4000            185                   235
# 3    A4  1.40  0.4128            203                   245
# 4    A5  1.20  0.4000            229                   253
# ..  ...   ...     ...            ...                   ...
# 76  C24  1.60  0.4016            177                   225
# 77  C25  1.60  0.4016            173                   216
# 78  C26  0.95  0.4016            126                   195
# 79  C28  1.70  0.4016            181                   216
# 80  C29  1.35  0.4230            166                   214
#
#     Đường kính dọc(mm)  Độ đường (Brix %)    TA (%)   Brix:TA      BrmTA  \
# 0                  262               10.9  4.867141  2.239508   6.032859
# 1                  278                9.8  3.073984  3.188045   6.726016
# 2                  237               11.0  5.891803  1.867001   5.108197
# 3                  245                9.0  3.701077  2.431725   5.298923
# 4                  249               10.9  3.073984  3.545887   7.826016
# ..                 ...                ...       ...       ...        ...
# 76                 216               12.5  4.115040  3.037638   8.384960
# 77                 220               11.1  4.115040  2.697422   6.984960
# 78                 197               12.8  2.443305  5.238806  10.356695
# 79                 232               11.8  4.372230  2.698852   7.427770
# 80                 214               12.3  3.657080  3.363339   8.642920
#
#              r           g          b  label_feature
# 0   139.332000  115.872000  28.152000      98.740000
# 1   147.213462  120.732692  33.934615      94.298077
# 2   160.854000  129.030000  33.966000      69.520000
# 3   158.814000  130.866000  30.906000      82.210000
# 4   144.636000  118.422000  36.414000      93.710000
# ..         ...         ...        ...            ...
# 76  140.352000  115.974000  34.068000      76.920000
# 77  149.226000  119.544000  35.802000      74.790000
# 78  131.682000  110.058000  31.620000      72.620000
# 79  143.106000  117.300000  35.496000      77.030000
# 80  138.108000  113.424000  31.926000      70.760000
#
# [81 rows x 14 columns]

# %%
numerical_cols = ['Khối lượng(g)', 'Đường kính ngang(mm)',
                'Đường kính dọc(mm)',
                'r', 'g', 'b']

data[numerical_cols].describe()
# Out:
#        Khối lượng(g)  Đường kính ngang(mm)  Đường kính dọc(mm)           r  \
# count      81.000000             81.000000           81.000000   81.000000
# mean      222.197531            241.777778          241.358025  142.794432
# std        50.582215             23.652167           22.587225   13.012212
# min       126.000000            195.000000          197.000000  117.096000
# 25%       179.000000            222.000000          223.000000  133.620000
# 50%       228.000000            242.000000          242.000000  140.454000
# 75%       255.000000            257.000000          255.000000  152.082000
# max       357.000000            305.000000          290.000000  181.254000
#
#                 g          b
# count   81.000000  81.000000
# mean   115.950431  34.273780
# std      9.596198   3.727668
# min     87.924000  23.256000
# 25%    112.302000  31.722000
# 50%    115.974000  34.068000
# 75%    121.278000  36.414000
# max    132.494845  41.310000

# %%
# Đếm số giá trị riêng biệt trong biến định lượng
distincts = []
percents = []
for numerical_col in numerical_cols:
  distinct = data[numerical_col].nunique()
  percent = distinct*100/data.shape[0]
  print(numerical_col, 'column has',distinct,'distinct values')
  print('It takes', format(percent,'.2f'),'%')
  print('---')
  distincts.append(distinct)
  percents.append(format(percent,'.2f')+'%')
dt = {'Count Distinct': distincts,'Take Percent':percents}

# Xem dưới dạng bảng thống kê
pd.DataFrame (data = dt, index = numerical_cols)
# Out:
# Khối lượng(g) column has 61 distinct values
# It takes 75.31 %
# ---
# Đường kính ngang(mm) column has 50 distinct values
# It takes 61.73 %
# ---
# Đường kính dọc(mm) column has 47 distinct values
# It takes 58.02 %
# ---
# r column has 74 distinct values
# It takes 91.36 %
# ---
# g column has 72 distinct values
# It takes 88.89 %
# ---
# b column has 65 distinct values
# It takes 80.25 %
# ---
#                       Count Distinct Take Percent
# Khối lượng(g)                     61       75.31%
# Đường kính ngang(mm)              50       61.73%
# Đường kính dọc(mm)                47       58.02%
# r                                 74       91.36%
# g                                 72       88.89%
# b                                 65       80.25%

# %%
# Visualize data
from sklearn import linear_model

# Khối lượng
x1 = data['Khối lượng(g)'].T

# Đường kính ngang
x2 = data['Đường kính ngang(mm)'].T

# Đường kính dọc
x3 = data['Đường kính dọc(mm)'].T

X = np.concatenate([x1, x2, x3])

# Độ đường
y = data['Độ đường (Brix %)'].T
print(y)
# Out:
# 0     10.9
# 1      9.8
# 2     11.0
# 3      9.0
# 4     10.9
#       ...
# 76    12.5
# 77    11.1
# 78    12.8
# 79    11.8
# 80    12.3
# Name: Độ đường (Brix %), Length: 81, dtype: float64

# %%
import matplotlib.pyplot as plt

# Visualize data
# Xem độ tương quan giữa lượng đường và khối lượng (g)
plt.scatter(x1,y)

# %%
plt.scatter(x2,y)

# %%
plt.scatter(x3,y)

# %%
import seaborn as sns
sns.scatterplot(x=data['Khối lượng(g)'],y=data['Độ đường (Brix %)'])
# Out:
# <Axes: xlabel='Khối lượng(g)', ylabel='Độ đường (Brix %)'>

# %% [markdown]
# ### 2. Feature Selection:
# - Choose features to train ML model

# %%
data.columns
# Out:
# Index(['Name', 'p', 'C NaOH', 'Khối lượng(g)', 'Đường kính ngang(mm)',
#        'Đường kính dọc(mm)', 'Độ đường (Brix %)', 'TA (%)', 'Brix:TA', 'BrmTA',
#        'r', 'g', 'b', 'label_feature'],
#       dtype='object')

# %%
features = ['Khối lượng(g)', 'Đường kính ngang(mm)',
            'Đường kính dọc(mm)',
            'r', 'g', 'b']

# %%
X = data[features]
y = data['Độ đường (Brix %)']

# %%
X.head()
# Out:
#    Khối lượng(g)  Đường kính ngang(mm)  Đường kính dọc(mm)           r  \
# 0            255                   257                 262  139.332000
# 1            325                   288                 278  147.213462
# 2            185                   235                 237  160.854000
# 3            203                   245                 245  158.814000
# 4            229                   253                 249  144.636000
#
#             g          b
# 0  115.872000  28.152000
# 1  120.732692  33.934615
# 2  129.030000  33.966000
# 3  130.866000  30.906000
# 4  118.422000  36.414000

# %%
y.head()
# Out:
# 0    10.9
# 1     9.8
# 2    11.0
# 3     9.0
# 4    10.9
# Name: Độ đường (Brix %), dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.7, test_size=0.3, random_state=0)

# %%
X_train
# Out:
#     Khối lượng(g)  Đường kính ngang(mm)  Đường kính dọc(mm)           r  \
# 43            207                   235                 231  152.082000
# 4             229                   253                 249  144.636000
# 72            143                   206                 207  135.762000
# 17            237                   255                 259  156.468000
# 63            179                   220                 220  135.864000
# 8             245                   255                 259  129.540000
# 6             309                   275                 285  145.962000
# 59            179                   221                 222  134.742000
# 38            258                   255                 251  133.620000
# 56            175                   215                 223  120.870000
# 34            214                   235                 236  152.184000
# 28            256                   252                 248  150.552000
# 11            294                   280                 280  157.488000
# 54            230                   245                 240  117.096000
# 23            310                   280                 281  153.000000
# 10            293                   268                 276  166.974000
# 31            213                   234                 235  131.172000
# 45            225                   238                 237  140.658000
# 78            126                   195                 197  131.682000
# 1             325                   288                 278  147.213462
# 32            254                   253                 251  136.884000
# 68            163                   215                 215  134.742000
# 14            255                   265                 255  161.874000
# 52            294                   269                 262  140.148000
# 19            247                   255                 255  144.534000
# 29            228                   242                 238  134.028000
# 60            173                   224                 215  162.996000
# 49            224                   243                 241  125.052000
# 24            265                   268                 278  138.312000
# 35            267                   257                 250  131.886000
# 18            256                   263                 260  131.981818
# 0             255                   257                 262  139.332000
# 79            181                   216                 232  143.106000
# 15            254                   260                 265  145.656000
# 5             357                   305                 290  135.896970
# 62            133                   199                 203  129.132000
# 16            231                   245                 247  143.004000
# 51            236                   242                 245  125.970000
# 20            318                   280                 282  160.418182
# 75            133                   198                 202  120.360000
# 25            260                   272                 260  137.908163
# 37            214                   234                 238  164.730000
# 46            221                   240                 241  139.026000
# 39            212                   235                 232  150.144000
# 65            185                   222                 223  127.296000
# 58            182                   220                 225  131.172000
# 12            272                   270                 269  152.898000
# 70            183                   223                 221  133.824000
# 36            238                   248                 249  146.880000
# 21            230                   255                 249  159.940206
# 9             275                   267                 270  148.716000
# 77            173                   216                 220  149.226000
# 67            156                   209                 214  137.802000
# 64            173                   216                 220  132.804000
# 47            234                   247                 247  145.044000
# 44            251                   257                 247  138.312000
#
#              g          b
# 43  120.564000  40.086000
# 4   118.422000  36.414000
# 72  113.730000  31.824000
# 17  129.336000  29.784000
# 63  113.832000  32.232000
# 8   114.852000  33.660000
# 6   119.136000  37.128000
# 59  111.486000  31.008000
# 38  112.710000  31.110000
# 56   90.780000  23.256000
# 34  121.890000  40.494000
# 28  121.074000  39.882000
# 11  126.990000  36.006000
# 54   87.924000  26.010000
# 23  122.400000  40.800000
# 10  131.478000  31.722000
# 31  110.772000  33.048000
# 45  115.362000  34.680000
# 78  110.058000  31.620000
# 1   120.732692  33.934615
# 32  112.812000  36.720000
# 68  112.302000  34.884000
# 14  129.642000  33.558000
# 52  115.974000  34.374000
# 19  125.868000  38.148000
# 29  112.812000  31.620000
# 60  117.504000  27.234000
# 49   97.206000  32.334000
# 24  115.974000  34.578000
# 35  110.466000  35.700000
# 18  113.539394  33.072727
# 0   115.872000  28.152000
# 79  117.300000  35.496000
# 15  122.094000  33.048000
# 5   114.878788  29.981818
# 62  108.834000  41.310000
# 16  117.708000  35.802000
# 51  100.470000  30.396000
# 20  130.436364  33.381818
# 75   96.594000  37.740000
# 25  120.110204  36.220408
# 37  118.014000  40.800000
# 46  108.528000  38.556000
# 39  120.462000  40.188000
# 65  103.326000  29.172000
# 58  109.344000  29.172000
# 12  122.400000  40.800000
# 70  112.812000  31.212000
# 36  119.340000  37.740000
# 21  132.494845  34.175258
# 9   124.338000  30.396000
# 77  119.544000  35.802000
# 67  114.750000  33.354000
# 64  110.670000  29.988000
# 47  117.912000  36.822000
# 44  114.954000  33.252000

# %%
print(X_train.shape, data.shape, X_valid.shape)
# Out:
# (56, 6) (81, 14) (25, 6)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,accuracy_score,r2_score

from math import sqrt

# creating the model
lrmodel = LinearRegression()

# feeding the training data to the model
lrmodel.fit(X_train, y_train)

# predicting the test set results
y_pred = lrmodel.predict(X_valid)

# calculating the mean squared error
MSE = mean_squared_error(y_valid, y_pred)
print('MSE: ', MSE)

# Calculating the root mean squared error
RMSE = sqrt(mean_squared_error(y_valid, y_pred))       
print('RMSE: ', RMSE)

# Calculating the r2 score
R2 = r2_score(y_valid, y_pred)
print('R2 :', R2)
# Out:
# MSE:  2.0037377796045024
# RMSE:  1.4155344501652025
# R2 : 0.14919893832436515

# %%
from sklearn.svm import SVR

# creating the model
svrmodel = SVR()

# feeding the training data to the model
svrmodel.fit(X_train, y_train)

# predicting the test set results
y_pred = svrmodel.predict(X_valid)

# calculating the mean squared error
MSE = mean_squared_error(y_valid, y_pred)
print('MSE: ', MSE)

# Calculating the root mean squared error
RMSE = sqrt(mean_squared_error(y_valid, y_pred))       
print('RMSE: ', RMSE)

# Calculating the r2 score
R2 = r2_score(y_valid, y_pred)
print('R2 :', R2)
# Out:
# MSE:  2.1255391744725034
# RMSE:  1.457922897300301
# R2 : 0.09748121501641671

# %%
from sklearn.tree import DecisionTreeRegressor

# creating the model
dtrmodel = DecisionTreeRegressor()

# feeding the training data to the model
dtrmodel.fit(X_train, y_train)

# predicting the test set results
y_pred = dtrmodel.predict(X_valid)

# calculating the mean squared error
MSE = mean_squared_error(y_valid, y_pred)
print('MSE: ', MSE)

# Calculating the root mean squared error
RMSE = sqrt(mean_squared_error(y_valid, y_pred))       
print('RMSE: ', RMSE)

# Calculating the r2 score
R2 = r2_score(y_valid, y_pred)
print('R2 :', R2)
# Out:
# MSE:  2.701884
# RMSE:  1.6437408554878716
# R2 : -0.14723882492156304

# %%
from sklearn.ensemble import RandomForestRegressor

# creating the model
#rfrmodel = RandomForestRegressor()
rfrmodel = RandomForestRegressor(n_estimators = 40, max_depth = 4, n_jobs = -1)

# feeding the training data to the model
rfrmodel.fit(X_train, y_train)

# predicting the test set results
y_pred = rfrmodel.predict(X_valid)

# calculating the mean squared error
MSE = mean_squared_error(y_valid, y_pred)
print('MSE: ', MSE)

# Calculating the root mean squared error
RMSE = sqrt(mean_squared_error(y_valid, y_pred))       
print('RMSE: ', RMSE)

# Calculating the r2 score
R2 = r2_score(y_valid, y_pred)
print('R2 :', R2)
# Out:
# MSE:  1.933965400657006
# RMSE:  1.3906708455479342
# R2 : 0.17882477793691243
